# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls'/content/drive/advertising.csv'
# Out:
# /bin/bash: line 1: ls/content/drive/advertising.csv: No such file or directory

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/My Drive /advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
X = df.drop('Sales',axis=1)

# %%
y = df['Sales']

# %%
for features in X.columns:
  plt.figure()
  plt.scatter(X[features],y)
  plt.title(f'Sales vs {features}')
  plt.xlabel('features')
  plt.ylabel('Sales')
  plt.show()

# %%
sns.scatterplot(X)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 114   78.2   46.8       34.5
# 173  168.4    7.1       12.8
# 5      8.7   48.9       75.0
# 126    7.8   38.9       50.6
# 117   76.4    0.8       14.8
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [150 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
y_test.shape
# Out:
# (50,)

# %%
x_test.shape
# Out:
# (50, 3)

# %%
lr = LinearRegression()

# %%
numeric = ['TV','Radio','Newspaper']

# %%
sns.boxplot(df[numeric],palette='coolwarm')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.distplot(df['Newspaper'])
# Out:
# <ipython-input-68-6fe4fcc6000a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Newspaper'])
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.histplot(df['Radio'],color='red')
plt.grid(True)
plt.show()

# %%
sns.violinplot(df[numeric],palette='coolwarm')
plt.show()

# %%
sns.scatterplot(x=df['TV'],y=df['Sales'])
plt.xlabel('TV')
plt.ylabel('Sales')
plt.title('Scatter plot of sales wrt TV')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# np.float64(4.741842244124568)

# %%
lr.coef_
# Out:
# array([0.05461383, 0.09975946, 0.00430495])

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
pd.DataFrame(y_pred,columns=['Predictions'])
# Out:
#     Predictions
# 0     17.040412
# 1     20.399644
# 2     23.747401
# 3      9.256532
# 4     21.675259
# 5     12.561793
# 6     21.078657
# 7      8.708955
# 8     17.283536
# 9     16.684919
# 10     8.925732
# 11     8.507626
# 12    18.253028
# 13     8.060031
# 14    12.684479
# 15    14.966775
# 16     8.121989
# 17    17.919062
# 18    11.019292
# 19    20.497906
# 20    20.817375
# 21    12.586621
# 22    10.888703
# 23    22.396922
# 24     9.441834
# 25     7.955327
# 26    20.837060
# 27    13.839972
# 28    10.792828
# 29     7.923096
# 30    16.004326
# 31    10.644969
# 32    20.790948
# 33    10.409167
# 34    21.617885
# 35    21.195423
# 36    12.104977
# 37    22.829703
# 38    12.632294
# 39     6.492450
# 40    11.944639
# 41    15.363806
# 42     9.910380
# 43     9.480034
# 44    17.281921
# 45     7.256609
# 46    10.369372
# 47    15.252936
# 48    11.171169
# 49    11.721142

# %%
#ploting graph

plt.scatter(y_test,y_pred)

plt.xlabel('y_test')
plt.ylabel('y_pred')

plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred)
plt.plot(y_test, y_test, color='red', label='Regression Line') # Plot the ideal line
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs. Predicted Sales')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
print("Mean Squared Error :",mse)
# Out:
# Mean Squared Error : 2.404067444711889

# %%
acc = r2_score(y_test,y_pred)
print('Accuracy Score :',acc*100,"%")
# Out:
# Accuracy Score : 91.15647723992757 %
